# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     127   )
#     128   if ephemeral:
# --> 129     _message.blocking_request(
#     130         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/home_insurance.csv/home_insurance.csv")

# %%
df.columns
# Out:
# Index(['QUOTE_DATE', 'COVER_START', 'CLAIM3YEARS', 'P1_EMP_STATUS',
#        'P1_PT_EMP_STATUS', 'BUS_USE', 'CLERICAL', 'AD_BUILDINGS',
#        'RISK_RATED_AREA_B', 'SUM_INSURED_BUILDINGS', 'NCD_GRANTED_YEARS_B',
#        'AD_CONTENTS', 'RISK_RATED_AREA_C', 'SUM_INSURED_CONTENTS',
#        'NCD_GRANTED_YEARS_C', 'CONTENTS_COVER', 'BUILDINGS_COVER',
#        'SPEC_SUM_INSURED', 'SPEC_ITEM_PREM', 'UNSPEC_HRP_PREM', 'P1_DOB',
#        'P1_MAR_STATUS', 'P1_POLICY_REFUSED', 'P1_SEX', 'APPR_ALARM',
#        'APPR_LOCKS', 'BEDROOMS', 'ROOF_CONSTRUCTION', 'WALL_CONSTRUCTION',
#        'FLOODING', 'LISTED', 'MAX_DAYS_UNOCC', 'NEIGH_WATCH', 'OCC_STATUS',
#        'OWNERSHIP_TYPE', 'PAYING_GUESTS', 'PROP_TYPE', 'SAFE_INSTALLED',
#        'SEC_DISC_REQ', 'SUBSIDENCE', 'YEARBUILT', 'CAMPAIGN_DESC',
#        'PAYMENT_METHOD', 'PAYMENT_FREQUENCY', 'LEGAL_ADDON_PRE_REN',
#        'LEGAL_ADDON_POST_REN', 'HOME_EM_ADDON_PRE_REN',
#        'HOME_EM_ADDON_POST_REN', 'GARDEN_ADDON_PRE_REN',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256136 entries, 0 to 256135
# Data columns (total 66 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   QUOTE_DATE              129524 non-null  object
#  1   COVER_START             189021 non-null  object
#  2   CLAIM3YEARS             190039 non-null  object
#  3   P1_EMP_STATUS           189021 non-null  object
#  4   P1_PT_EMP_STATUS        1782 non-null    object
#  5   BUS_USE                 189021 non-null  object
#  6   CLERICAL                2944 non-null    object
#  7   AD_BUILDINGS            189021 non-null  object
#  8   RISK_RATED_AREA_B       140876 non-null  float64
#  9   SUM_INSURED_BUILDINGS   189021 non-null  float64
#  10  NCD_GRANTED_YEARS_B     189021 non-null  float64
#  11  AD_CONTENTS             189021 non-null  object
#  12  RISK_RATED_AREA_C       180290 non-null  float64
#  13  SUM_INSURED_CONTENTS    189021 non-null  float64
# ...

# %%
for column in df.columns:
  print(f"{column}:{df[column].dtype}")
# Out:
# QUOTE_DATE:object
# COVER_START:object
# CLAIM3YEARS:object
# P1_EMP_STATUS:object
# P1_PT_EMP_STATUS:object
# BUS_USE:object
# CLERICAL:object
# AD_BUILDINGS:object
# RISK_RATED_AREA_B:float64
# SUM_INSURED_BUILDINGS:float64
# NCD_GRANTED_YEARS_B:float64
# AD_CONTENTS:object
# RISK_RATED_AREA_C:float64
# SUM_INSURED_CONTENTS:float64
# NCD_GRANTED_YEARS_C:float64
# CONTENTS_COVER:object
# BUILDINGS_COVER:object
# SPEC_SUM_INSURED:float64
# SPEC_ITEM_PREM:float64
# UNSPEC_HRP_PREM:float64
# P1_DOB:object
# P1_MAR_STATUS:object
# P1_POLICY_REFUSED:object
# P1_SEX:object
# APPR_ALARM:object
# APPR_LOCKS:object
# BEDROOMS:float64
# ROOF_CONSTRUCTION:float64
# WALL_CONSTRUCTION:float64
# FLOODING:object
# LISTED:float64
# MAX_DAYS_UNOCC:float64
# NEIGH_WATCH:object
# OCC_STATUS:object
# OWNERSHIP_TYPE:float64
# PAYING_GUESTS:float64
# PROP_TYPE:float64
# SAFE_INSTALLED:object
# SEC_DISC_REQ:object
# SUBSIDENCE:object
# YEARBUILT:float64
# CAMPAIGN_DESC:float64
# PAYMENT_METHOD:object
# ...

# %%
df.shape
# Out:
# (256136, 66)

# %%
df.dtypes
# Out:
# QUOTE_DATE              object
# COVER_START             object
# CLAIM3YEARS             object
# P1_EMP_STATUS           object
# P1_PT_EMP_STATUS        object
#                         ...
# MTA_DATE                object
# LAST_ANN_PREM_GROSS    float64
# POL_STATUS              object
# i                        int64
# Police                  object
# Length: 66, dtype: object

# %%
df.describe()
# Out:
#        RISK_RATED_AREA_B  SUM_INSURED_BUILDINGS  NCD_GRANTED_YEARS_B  \
# count      140876.000000          189021.000000        189021.000000
# mean           10.274440          778130.472276             4.477132
# std             8.449942          415504.938301             2.677538
# min             0.000000               0.000000             0.000000
# 25%             3.000000         1000000.000000             3.000000
# 50%             9.000000         1000000.000000             6.000000
# 75%            14.000000         1000000.000000             6.000000
# max            98.000000         1000000.000000             9.000000
#
#        RISK_RATED_AREA_C  SUM_INSURED_CONTENTS  NCD_GRANTED_YEARS_C  \
# count      180290.000000         189021.000000        189021.000000
# mean            9.055649          47836.219256             5.497336
# std             7.624659          10706.355022             1.777452
# min             0.000000              0.000000             0.000000
# ...

# %%
print(df.isnull().sum())
# Out:
# QUOTE_DATE             126612
# COVER_START             67115
# CLAIM3YEARS             66097
# P1_EMP_STATUS           67115
# P1_PT_EMP_STATUS       254354
#                         ...
# MTA_DATE               229561
# LAST_ANN_PREM_GROSS     66097
# POL_STATUS              67115
# i                           0
# Police                      0
# Length: 66, dtype: int64

# %%
df.describe()
# Out:
#        RISK_RATED_AREA_B  SUM_INSURED_BUILDINGS  NCD_GRANTED_YEARS_B  \
# count      140876.000000          189021.000000        189021.000000
# mean           10.274440          778130.472276             4.477132
# std             8.449942          415504.938301             2.677538
# min             0.000000               0.000000             0.000000
# 25%             3.000000         1000000.000000             3.000000
# 50%             9.000000         1000000.000000             6.000000
# 75%            14.000000         1000000.000000             6.000000
# max            98.000000         1000000.000000             9.000000
#
#        RISK_RATED_AREA_C  SUM_INSURED_CONTENTS  NCD_GRANTED_YEARS_C  \
# count      180290.000000         189021.000000        189021.000000
# mean            9.055649          47836.219256             5.497336
# std             7.624659          10706.355022             1.777452
# min             0.000000              0.000000             0.000000
# ...

# %%
# df.shape
# Out:
# (256136, 66)

# %%
df.head(20)
# Out:
#     QUOTE_DATE COVER_START CLAIM3YEARS P1_EMP_STATUS P1_PT_EMP_STATUS BUS_USE  \
# 0   11/22/2007  22/11/2007           N             R              NaN       N
# 1   11/22/2007  01/01/2008           N             E              NaN       Y
# 2   11/23/2007  23/11/2007           N             E              NaN       N
# 3   11/23/2007  12/12/2007           N             R              NaN       N
# 4   11/22/2007  15/12/2007           N             R              NaN       N
# 5   11/22/2007  01/12/2007           N             R              NaN       N
# 6   11/19/2007  12/12/2007           N             R              NaN       N
# 7   11/22/2007  01/12/2007           N             R              NaN       N
# 8   11/22/2007  01/02/2008           N             E              NaN       N
# 9   11/22/2007  01/12/2007           N             E              NaN       N
# 10  11/22/2007  07/12/2007           N             R              NaN       N
# ...

# %%
df.drop('P1_PT_EMP_STATUS',axis = 1, inplace = True)

# %%
df.shape
# Out:
# (256136, 65)

# %%
df.isna().sum(axis=0).T
# Out:
# QUOTE_DATE             126612
# COVER_START             67115
# CLAIM3YEARS             66097
# P1_EMP_STATUS           67115
# BUS_USE                 67115
#                         ...
# MTA_DATE               229561
# LAST_ANN_PREM_GROSS     66097
# POL_STATUS              67115
# i                           0
# Police                      0
# Length: 65, dtype: int64

# %%
a=df.isnull().sum()/df.shape[0]
a
# Out:
# QUOTE_DATE             0.494316
# COVER_START            0.262029
# CLAIM3YEARS            0.258054
# P1_EMP_STATUS          0.262029
# BUS_USE                0.262029
#                          ...
# MTA_DATE               0.896247
# LAST_ANN_PREM_GROSS    0.258054
# POL_STATUS             0.262029
# i                      0.000000
# Police                 0.000000
# Length: 65, dtype: float64

# %%
df.shape
# Out:
# (178282, 65)

# %%
df.dropna(axis = 0 , how = 'any')
# Out:
# Empty DataFrame
# ...

# %%
#df = pd.DataFrame('home_insurance.csv')

# Calculate the threshold for 50% null values
threshold = len(df) * 0.8

# Remove columns with more than 50% null values
df_filtered = df.dropna(thresh=threshold, axis=1)

print(df_filtered)
# Out:
#              i   Police
# 0            1  P000001
# 1            2  P000002
# 2            3  P000003
# 3            4  P000004
# 4            5  P000005
# ...        ...      ...
# 256131  256132  P256132
# 256132  256133  P256133
# 256133  256134  P256134
# 256134  256135  P256135
# 256135  256136  P256136
#
# [256136 rows x 2 columns]

# %%
df_filtered.shape
# Out:
# (256136, 2)

# %%
df_filtered.isna().sum()
# Out:
# QUOTE_DATE                88402
# COVER_START               46460
# CLAIM3YEARS               45721
# P1_EMP_STATUS             46460
# BUS_USE                   46460
# AD_BUILDINGS              46460
# RISK_RATED_AREA_B         80153
# SUM_INSURED_BUILDINGS     46460
# NCD_GRANTED_YEARS_B       46460
# AD_CONTENTS               46460
# RISK_RATED_AREA_C         52553
# SUM_INSURED_CONTENTS      46460
# NCD_GRANTED_YEARS_C       46460
# CONTENTS_COVER            46460
# BUILDINGS_COVER           46460
# SPEC_SUM_INSURED          46460
# SPEC_ITEM_PREM            46460
# UNSPEC_HRP_PREM           46460
# P1_DOB                    46460
# P1_MAR_STATUS             46460
# P1_POLICY_REFUSED         46460
# P1_SEX                    46460
# APPR_ALARM                46460
# APPR_LOCKS                46460
# BEDROOMS                  46460
# ROOF_CONSTRUCTION         46460
# WALL_CONSTRUCTION         46460
# FLOODING                  46460
# LISTED                    46460
# ...

# %%
# Find unique values in the entire DataFrame
unique_values_df = df_filtered.apply(pd.Series.nunique)

# %%
print(unique_values_df==1)
# Out:
# QUOTE_DATE                False
# COVER_START               False
# CLAIM3YEARS               False
# P1_EMP_STATUS             False
# BUS_USE                   False
# AD_BUILDINGS              False
# RISK_RATED_AREA_B         False
# SUM_INSURED_BUILDINGS     False
# NCD_GRANTED_YEARS_B       False
# AD_CONTENTS               False
# RISK_RATED_AREA_C         False
# SUM_INSURED_CONTENTS      False
# NCD_GRANTED_YEARS_C       False
# CONTENTS_COVER            False
# BUILDINGS_COVER           False
# SPEC_SUM_INSURED          False
# SPEC_ITEM_PREM            False
# UNSPEC_HRP_PREM           False
# P1_DOB                    False
# P1_MAR_STATUS             False
# P1_POLICY_REFUSED         False
# P1_SEX                    False
# APPR_ALARM                False
# APPR_LOCKS                False
# BEDROOMS                  False
# ROOF_CONSTRUCTION         False
# WALL_CONSTRUCTION         False
# FLOODING                  False
# LISTED                    False
# ...

# %%
df_filtered = df_filtered.drop('PAYMENT_FREQUENCY',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-4f4460db28bb> in <cell line: 1>()
# ----> 1 df_filtered = df_filtered.drop('PAYMENT_FREQUENCY',axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
df_filtered.shape
# Out:
# (178282, 59)

# %%
# remove null rows from dataset
df_filtered = df_filtered.dropna()

# %%
df_filtered.shape
# Out:
# (40372, 59)

# %%
df_filtered.columns
# Out:
# Index(['QUOTE_DATE', 'COVER_START', 'CLAIM3YEARS', 'P1_EMP_STATUS', 'BUS_USE',
#        'AD_BUILDINGS', 'RISK_RATED_AREA_B', 'SUM_INSURED_BUILDINGS',
#        'NCD_GRANTED_YEARS_B', 'AD_CONTENTS', 'RISK_RATED_AREA_C',
#        'SUM_INSURED_CONTENTS', 'NCD_GRANTED_YEARS_C', 'CONTENTS_COVER',
#        'BUILDINGS_COVER', 'SPEC_SUM_INSURED', 'SPEC_ITEM_PREM',
#        'UNSPEC_HRP_PREM', 'P1_DOB', 'P1_MAR_STATUS', 'P1_POLICY_REFUSED',
#        'P1_SEX', 'APPR_ALARM', 'APPR_LOCKS', 'BEDROOMS', 'ROOF_CONSTRUCTION',
#        'WALL_CONSTRUCTION', 'FLOODING', 'LISTED', 'MAX_DAYS_UNOCC',
#        'NEIGH_WATCH', 'OCC_STATUS', 'OWNERSHIP_TYPE', 'PAYING_GUESTS',
#        'PROP_TYPE', 'SAFE_INSTALLED', 'SEC_DISC_REQ', 'SUBSIDENCE',
#        'YEARBUILT', 'PAYMENT_METHOD', 'LEGAL_ADDON_PRE_REN',
#        'LEGAL_ADDON_POST_REN', 'HOME_EM_ADDON_PRE_REN',
#        'HOME_EM_ADDON_POST_REN', 'GARDEN_ADDON_PRE_REN',
#        'GARDEN_ADDON_POST_REN', 'KEYCARE_ADDON_PRE_REN',
# ...

# %%
df_filtered.duplicated().sum()
# Out:
# 0

# %%
################################################
object_columns =[]
for column in df.columns:
  if df[column].dtype == 'object':
        object_columns.append(column)
print(object_columns)

for column in object_columns:
    encoded_column = pd.get_dummies(df[column], prefix=f'encoded_{column}')
    df = pd.concat([df, encoded_column], axis=1)
    df.drop(column, axis=1, inplace=True)
